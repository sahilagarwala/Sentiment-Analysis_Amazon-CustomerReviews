# %%
# Library Load Model
import pandas as pd
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Library Pre-Processing
from nltk.stem import WordNetLemmatizer
import nltk
import re
import string
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import pickle
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# loading token
with open('t.pickle', 'rb') as file_1:
    t = pickle.load(file_1)

# %%
# Load Model
  
model_gruimp = load_model('best_model.h5')

# %%
model_gruimp.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 102, 128)          6469120
#
#  bidirectional (Bidirectiona  (None, 102, 64)          31104
#  l)
#
#  gru_1 (GRU)                 (None, 8)                 1776
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 6,502,009
# Trainable params: 0
# Non-trainable params: 6,502,009
# _________________________________________________________________

# %%
# Adding spanish to stopwords
spanish = stopwords.words('spanish')
additional_stopwords = []
for i in spanish:
    additional_stopwords.append(i)

# Adding french to stopwords
french = stopwords.words('french')
for i in french:
    additional_stopwords.append(i)

# Adding german to stopwords
german = stopwords.words('german')
for i in german:
    additional_stopwords.append(i)

# %%
# Setting stopwords with english as default language
stopwords = list(set(stopwords.words('english')))
for i in additional_stopwords:
    stopwords.append(i)

# %%
lemmatizer = WordNetLemmatizer()
def text_processing(text):

    # Converting all text to Lowercase
    text = text.lower()

    # Removing Unicode Characters
    text = re.sub("&#[A-Za-z0-9_]+", " ", text)

    # Removing punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
  
    # Removing Whitespace
    text = text.strip()

    # Removing emoji
    text = re.sub("[^A-Za-z\s']", " ", text)

    # Removing double space
    text = re.sub("\s\s+" , " ", text)
        
    # Tokenizing words
    tokens = word_tokenize(text)

    # Removing Stopwords
    text = ' '.join([word for word in tokens if word not in stopwords])

    # Lemmatizer
    text = lemmatizer.lemmatize(text)

    return text

# %%
df_inf = pd.read_csv('model_inference_sentiment_analysis.csv')
df_inf_copy = df_inf.copy()
df_inf_copy = df_inf.drop(['Unnamed: 0'],axis=1)
df_inf_copy.class_index.replace({1:'Negative Review',2:'Positive Review'}, inplace=True)

# %%
df_inf_copy
# Out:
#        class_index                                     review_title  \
# 0  Positive Review  This Or "Dixie Chicken" Presents Them At A Peak
# 1  Positive Review                 It's not perfect, but very good!
# 2  Positive Review                                        Well done
# 3  Negative Review                  Not so great, but pretty colors
# 4  Negative Review                       Ruined My Valentine's Day!
# 5  Positive Review                     Concise Text of Neuroscience
# 6  Positive Review                                       GREAT!!!!!
# 7  Positive Review                                       Hot Coffee
# 8  Positive Review                     Mystery at Walt Disney World
# 9  Negative Review                Take with a dose of skepticism...
#
#                                          review_text
# 0  Though lyrically the overall feel of this reco...
# 1  I have been looking for an anthology of outsta...
# 2  While the characters are not the same as in th...
# 3  I tried/own both the pink and the orangish col...
# 4  I read each Amazon review on this product befo...
# 5  I bought this book for my brother as he is tak...
# 6  I got this toy a couple of days ago and I ABSO...
# 7  Good coffee pot. Hot coffee. 6-8 cups makes a ...
# 8  Book arrived in good condition, but took quite...
# 9  All readers should keep in mind that, as anoth...

# %%
# Applying all preprocessing in one document

df_inf_copy['review_processed'] = df_inf_copy['review_text'].apply(lambda x: text_processing(x))
df_inf_copy
# Out:
#        class_index                                     review_title  \
# 0  Positive Review  This Or "Dixie Chicken" Presents Them At A Peak
# 1  Positive Review                 It's not perfect, but very good!
# 2  Positive Review                                        Well done
# 3  Negative Review                  Not so great, but pretty colors
# 4  Negative Review                       Ruined My Valentine's Day!
# 5  Positive Review                     Concise Text of Neuroscience
# 6  Positive Review                                       GREAT!!!!!
# 7  Positive Review                                       Hot Coffee
# 8  Positive Review                     Mystery at Walt Disney World
# 9  Negative Review                Take with a dose of skepticism...
#
#                                          review_text  \
# 0  Though lyrically the overall feel of this reco...
# 1  I have been looking for an anthology of outsta...
# 2  While the characters are not the same as in th...
# 3  I tried/own both the pink and the orangish col...
# 4  I read each Amazon review on this product befo...
# 5  I bought this book for my brother as he is tak...
# 6  I got this toy a couple of days ago and I ABSO...
# 7  Good coffee pot. Hot coffee. 6-8 cups makes a ...
# 8  Book arrived in good condition, but took quite...
# 9  All readers should keep in mind that, as anoth...
#
#                                     review_processed
# 0  though lyrically overall feel record slightly ...
# 1  looking anthology outstanding literary materia...
# 2  characters original casting well done players ...
# 3  triedown pink orangish colors work way true go...
# 4  read amazon review product made purchase full ...
# 5  bought book brother taking class using book lo...
# 6  got toy couple days ago absolutely love much r...
# 7  good coffee pot hot coffee cups makes strong c...
# 8  book arrived good condition took quite bit lon...
# 9  readers keep mind another reviewer noted arno ...

# %%
# Transform Inference-Set 
df_inf_transform = df_inf_copy.review_processed

# %%
word_index = t.word_index

# %%
word_index
# Out:
# {'<UNK>': 1,
#  'time': 2,
#  'movie': 3,
#  'even': 4,
#  'well': 5,
#  'love': 6,
#  'use': 7,
#  'better': 8,
#  'product': 9,
#  'bought': 10,
#  'work': 11,
#  'cd': 12,
#  'little': 13,
#  'album': 14,
#  'best': 15,
#  'think': 16,
#  'story': 17,
#  'make': 18,
#  'got': 19,
#  'two': 20,
#  'know': 21,
#  'still': 22,
#  'music': 23,
#  'years': 24,
#  'never': 25,
#  'want': 26,
#  'ive': 27,
#  'see': 28,
#  'people': 29,
#  'money': 30,
#  'books': 31,
#  'made': 32,
#  'find': 33,
#  'didnt': 34,
#  'recommend': 35,
#  'bad': 36,
#  'ever': 37,
#  'used': 38,
#  'found': 39,
#  'go': 40,
#  'put': 41,
#  'another': 42,
#  'cant': 43,
#  'reading': 44,
#  'say': 45,
#  'songs': 46,
#  'quality': 47,
#  'every': 48,
#  'something': 49,
#  'thing': 50,
#  'doesnt': 51,
#  'life': 52,
#  'easy': 53,
#  'thought': 54,
#  'game': 55,
#  'lot': 56,
#  'dvd': 57,
#  'however': 58,
#  'worth': 59,
#  'long': 60,
#  'give': 61,
#  'hard': 62,
#  'since': 63,
#  'need': 64,
#  'sound': 65,
#  'looking': 66,
#  'going': 67,
#  'characters': 68,
#  'film': 69,
#  'real': 70,
#  'makes': 71,
#  'anyone': 72,
#  'enough': 73,
#  'take': 74,
#  'different': 75,
#  'last': 76,
#  'year': 77,
#  'set': 78,
#  'right': 79,
#  'price': 80,
#  'look': 81,
#  'nothing': 82,
#  'times': 83,
#  'day': 84,
#  'nice': 85,
#  'must': 86,
#  'works': 87,
#  'end': 88,
#  'though': 89,
#  'author': 90,
#  'without': 91,
#  'amazon': 92,
#  'series': 93,
#  'feel': 94,
#  'away': 95,
#  'fan': 96,
#  'far': 97,
#  'purchased': 98,
#  'around': 99,
#  'sure': 100,
#  'watch': 101,
#  'us': 102,
#  'using': 103,
#  'problem': 104,
#  'things': 105,
#  'pretty': 106,
#  'written': 107,
#  'may': 108,
#  'always': 109,
#  'song': 110,
#  'reviews': 111,
#  'big': 112,
#  'come': 113,
#  'play': 114,
#  'came': 115,
#  'actually': 116,
#  'disappointed': 117,
#  'keep': 118,
#  'waste': 119,
#  'fun': 120,
#  'anything': 121,
#  'bit': 122,
#  'world': 123,
#  'seems': 124,
#  'show': 125,
#  'excellent': 126,
#  'version': 127,
#  'small': 128,
#  'tried': 129,
#  'almost': 130,
#  'thats': 131,
#  'try': 132,
#  'done': 133,
#  'isnt': 134,
#  'yet': 135,
#  'loved': 136,
#  'item': 137,
#  'part': 138,
#  'writing': 139,
#  'interesting': 140,
#  'original': 141,
#  'next': 142,
#  'quite': 143,
#  'less': 144,
#  'enjoy': 145,
#  'getting': 146,
#  'second': 147,
#  'youre': 148,
#  'everything': 149,
#  'whole': 150,
#  'seen': 151,
#  'plot': 152,
#  'months': 153,
#  'said': 154,
#  'stars': 155,
#  'help': 156,
#  'able': 157,
#  'highly': 158,
#  'received': 159,
#  'might': 160,
#  'least': 161,
#  'trying': 162,
#  'band': 163,
#  'high': 164,
#  'maybe': 165,
#  'information': 166,
#  'short': 167,
#  'instead': 168,
#  'wonderful': 169,
#  'wanted': 170,
#  'several': 171,
#  'together': 172,
#  'purchase': 173,
#  'probably': 174,
#  'believe': 175,
#  'went': 176,
#  'days': 177,
#  'wont': 178,
#  'movies': 179,
#  'others': 180,
#  'live': 181,
#  'wish': 182,
#  'perfect': 183,
#  'ordered': 184,
#  'full': 185,
#  'couldnt': 186,
#  'definitely': 187,
#  'someone': 188,
#  'video': 189,
#  'buying': 190,
#  'ago': 191,
#  'wasnt': 192,
#  'heard': 193,
#  'light': 194,
#  'started': 195,
#  'already': 196,
#  'three': 197,
#  'especially': 198,
#  'took': 199,
#  'favorite': 200,
#  'true': 201,
#  'wrong': 202,
#  'job': 203,
#  'box': 204,
#  'fine': 205,
#  'enjoyed': 206,
#  'review': 207,
#  'id': 208,
#  'worked': 209,
#  'kind': 210,
#  'fact': 211,
#  'star': 212,
#  'although': 213,
#  'point': 214,
#  'kids': 215,
#  'character': 216,
#  'pages': 217,
#  'style': 218,
#  'worst': 219,
#  'family': 220,
#  'minutes': 221,
#  'collection': 222,
#  'understand': 223,
#  'boring': 224,
#  'case': 225,
#  'else': 226,
#  'top': 227,
#  'novel': 228,
#  'home': 229,
#  'place': 230,
#  'happy': 231,
#  'left': 232,
#  'looks': 233,
#  'water': 234,
#  'comes': 235,
#  'listen': 236,
#  'half': 237,
#  'voice': 238,
#  'hope': 239,
#  'fit': 240,
#  'gave': 241,
#  'liked': 242,
#  'phone': 243,
#  'history': 244,
#  'order': 245,
#  'cover': 246,
#  'rather': 247,
#  'unit': 248,
#  'funny': 249,
#  'ones': 250,
#  'beautiful': 251,
#  'line': 252,
#  'start': 253,
#  'gets': 254,
#  'hear': 255,
#  'couple': 256,
#  'let': 257,
#  'sounds': 258,
#  'problems': 259,
#  'return': 260,
#  'poor': 261,
#  'size': 262,
#  'making': 263,
#  'piece': 264,
#  'cheap': 265,
#  'children': 266,
#  'page': 267,
#  'reason': 268,
#  'saw': 269,
#  'simply': 270,
#  'takes': 271,
#  'seem': 272,
#  'either': 273,
#  'tell': 274,
#  'completely': 275,
#  'wouldnt': 276,
#  'everyone': 277,
#  'reader': 278,
#  'working': 279,
#  'hours': 280,
#  'needed': 281,
#  'thinking': 282,
#  'tv': 283,
#  'side': 284,
#  'felt': 285,
#  'watching': 286,
#  'learn': 287,
#  'along': 288,
#  'stuff': 289,
#  'called': 290,
#  'friends': 291,
#  'camera': 292,
#  'guess': 293,
#  'amazing': 294,
#  'idea': 295,
#  'absolutely': 296,
#  'etc': 297,
#  'rock': 298,
#  'person': 299,
#  'stories': 300,
#  'mind': 301,
#  'playing': 302,
#  'overall': 303,
#  'ok': 304,
#  'young': 305,
#  'player': 306,
#  'youll': 307,
#  'please': 308,
#  'course': 309,
#  'power': 310,
#  'difficult': 311,
#  'plastic': 312,
#  'needs': 313,
#  'picture': 314,
#  'ill': 315,
#  'simple': 316,
#  'easily': 317,
#  'weeks': 318,
#  'black': 319,
#  'finally': 320,
#  'classic': 321,
#  'shows': 322,
#  'extremely': 323,
#  'daughter': 324,
#  'wait': 325,
#  'complete': 326,
#  'rest': 327,
#  'pay': 328,
#  'save': 329,
#  'hold': 330,
#  'truly': 331,
#  'color': 332,
#  'theres': 333,
#  'support': 334,
#  'past': 335,
#  'special': 336,
#  'battery': 337,
#  'christmas': 338,
#  'later': 339,
#  'school': 340,
#  'goes': 341,
#  'entire': 342,
#  'night': 343,
#  'longer': 344,
#  'often': 345,
#  'pictures': 346,
#  'fast': 347,
#  'gives': 348,
#  'track': 349,
#  'store': 350,
#  'material': 351,
#  'given': 352,
#  'havent': 353,
#  'company': 354,
#  'loves': 355,
#  'lost': 356,
#  'parts': 357,
#  'computer': 358,
#  'experience': 359,
#  'week': 360,
#  'gift': 361,
#  'house': 362,
#  'words': 363,
#  'expected': 364,
#  'unfortunately': 365,
#  'within': 366,
#  'fans': 367,
#  'copy': 368,
#  'child': 369,
#  'recommended': 370,
#  'low': 371,
#  'seemed': 372,
#  'told': 373,
#  'slow': 374,
#  'toy': 375,
#  'service': 376,
#  'write': 377,
#  'authors': 378,
#  'played': 379,
#  'system': 380,
#  'mr': 381,
#  'large': 382,
#  'kept': 383,
#  'brand': 384,
#  'available': 385,
#  'tracks': 386,
#  'turn': 387,
#  'hand': 388,
#  'sometimes': 389,
#  'lots': 390,
#  'stay': 391,
#  'sent': 392,
#  'action': 393,
#  'cut': 394,
#  'title': 395,
#  'release': 396,
#  'close': 397,
#  'products': 398,
#  'type': 399,
#  'sense': 400,
#  'change': 401,
#  'care': 402,
#  'horrible': 403,
#  'metal': 404,
#  'coffee': 405,
#  'awesome': 406,
#  'listening': 407,
#  'hair': 408,
#  'shipping': 409,
#  'season': 410,
#  'totally': 411,
#  'quickly': 412,
#  'month': 413,
#  'says': 414,
#  'god': 415,
#  'run': 416,
#  'based': 417,
#  'open': 418,
#  'clear': 419,
#  'husband': 420,
#  'albums': 421,
#  'name': 422,
#  'car': 423,
#  'four': 424,
#  'guy': 425,
#  'disc': 426,
#  'friend': 427,
#  'baby': 428,
#  'cool': 429,
#  'free': 430,
#  'number': 431,
#  'girl': 432,
#  'acting': 433,
#  'broke': 434,
#  'card': 435,
#  'expect': 436,
#  'batteries': 437,
#  'returned': 438,
#  'add': 439,
#  'looked': 440,
#  'terrible': 441,
#  'interested': 442,
#  'main': 443,
#  'white': 444,
#  'inside': 445,
#  'early': 446,
#  'cable': 447,
#  'today': 448,
#  'ending': 449,
#  'guys': 450,
#  'remember': 451,
#  'machine': 452,
#  'cost': 453,
#  'head': 454,
#  'opinion': 455,
#  'decided': 456,
#  'theyre': 457,
#  'hot': 458,
#  'matter': 459,
#  'plus': 460,
#  'spend': 461,
#  'yes': 462,
#  'stop': 463,
#  'american': 464,
#  'usually': 465,
#  'heavy': 466,
#  'scenes': 467,
#  'edition': 468,
#  'check': 469,
#  'previous': 470,
#  'games': 471,
#  'level': 472,
#  'extra': 473,
#  'design': 474,
#  'cds': 475,
#  'strong': 476,
#  'glad': 477,
#  'room': 478,
#  'lyrics': 479,
#  'food': 480,
#  'finish': 481,
#  'paid': 482,
#  'single': 483,
#  'five': 484,
#  'except': 485,
#  'useful': 486,
#  'arrived': 487,
#  'forward': 488,
#  'face': 489,
#  'software': 490,
#  'call': 491,
#  'pick': 492,
#  'agree': 493,
#  'replacement': 494,
#  'clean': 495,
#  'chapter': 496,
#  'hes': 497,
#  'ideas': 498,
#  'exactly': 499,
#  'watched': 500,
#  'mine': 501,
#  'screen': 502,
#  'stand': 503,
#  'follow': 504,
#  'deal': 505,
#  'unless': 506,
#  'huge': 507,
#  'important': 508,
#  'features': 509,
#  'coming': 510,
#  'sorry': 511,
#  'certainly': 512,
#  'heart': 513,
#  'knew': 514,
#  'woman': 515,
#  'turned': 516,
#  'taking': 517,
#  'beginning': 518,
#  'move': 519,
#  'seller': 520,
#  'word': 521,
#  'paper': 522,
#  'recording': 523,
#  'scene': 524,
#  'customer': 525,
#  'taste': 526,
#  'dog': 527,
#  'older': 528,
#  'entertaining': 529,
#  'th': 530,
#  'radio': 531,
#  'business': 532,
#  'basic': 533,
#  'decent': 534,
#  'example': 535,
#  'age': 536,
#  'replace': 537,
#  'fall': 538,
#  'happened': 539,
#  'issues': 540,
#  'subject': 541,
#  'soon': 542,
#  'text': 543,
#  'gone': 544,
#  'issue': 545,
#  'online': 546,
#  'lack': 547,
#  'group': 548,
#  'women': 549,
#  'hate': 550,
#  'hour': 551,
#  'supposed': 552,
#  'pieces': 553,
#  'due': 554,
#  'english': 555,
#  'comfortable': 556,
#  'wife': 557,
#  'effects': 558,
#  'hit': 559,
#  'beat': 560,
#  'worse': 561,
#  'serious': 562,
#  'description': 563,
#  'spent': 564,
#  'model': 565,
#  'useless': 566,
#  'record': 567,
#  'expensive': 568,
#  'class': 569,
#  'keeps': 570,
#  'package': 571,
#  'volume': 572,
#  'stopped': 573,
#  'stick': 574,
#  'language': 575,
#  'john': 576,
#  'guitar': 577,
#  'mean': 578,
#  'taken': 579,
#  'quick': 580,
#  'awful': 581,
#  'tape': 582,
#  'poorly': 583,
#  'pop': 584,
#  'similar': 585,
#  'uses': 586,
#  'become': 587,
#  'annoying': 588,
#  'space': 589,
#  'list': 590,
#  'included': 591,
#  'living': 592,
#  'fantastic': 593,
#  'ended': 594,
#  'handle': 595,
#  'writer': 596,
#  'stupid': 597,
#  'dark': 598,
#  'films': 599,
#  'thank': 600,
#  'performance': 601,
#  'perhaps': 602,
#  'hoping': 603,
#  'art': 604,
#  'front': 605,
#  'figure': 606,
#  'happen': 607,
#  'blue': 608,
#  'country': 609,
#  'otherwise': 610,
#  'saying': 611,
#  'purchasing': 612,
#  'weight': 613,
#  'control': 614,
#  'actual': 615,
#  'greatest': 616,
#  'death': 617,
#  'bag': 618,
#  'helpful': 619,
#  'hands': 620,
#  'value': 621,
#  'wants': 622,
#  'giving': 623,
#  'arent': 624,
#  'view': 625,
#  'human': 626,
#  'known': 627,
#  'including': 628,
#  'instructions': 629,
#  'mother': 630,
#  'released': 631,
#  'disappointing': 632,
#  'sad': 633,
#  'body': 634,
#  'feeling': 635,
#  'interest': 636,
#  'running': 637,
#  'boy': 638,
#  'major': 639,
#  'thanks': 640,
#  'realize': 641,
#  'library': 642,
#  'regular': 643,
#  'wrote': 644,
#  'drive': 645,
#  'oh': 646,
#  'actors': 647,
#  'perfectly': 648,
#  'lines': 649,
#  'twice': 650,
#  'install': 651,
#  'personal': 652,
#  'addition': 653,
#  'amount': 654,
#  'finished': 655,
#  'print': 656,
#  'suggest': 657,
#  'break': 658,
#  'bottom': 659,
#  'throughout': 660,
#  'research': 661,
#  'seeing': 662,
#  'loud': 663,
#  'guide': 664,
#  'broken': 665,
#  'talent': 666,
#  'behind': 667,
#  'bands': 668,
#  'local': 669,
#  'cute': 670,
#  'wear': 671,
#  'missing': 672,
#  'surprised': 673,
#  'advice': 674,
#  'apart': 675,
#  'recently': 676,
#  'dead': 677,
#  'effort': 678,
#  'date': 679,
#  'program': 680,
#  'air': 681,
#  'total': 682,
#  'deep': 683,
#  'means': 684,
#  'area': 685,
#  'leave': 686,
#  'clearly': 687,
#  'youve': 688,
#  'knows': 689,
#  'expecting': 690,
#  'production': 691,
#  'musical': 692,
#  'modern': 693,
#  'red': 694,
#  'across': 695,
#  'disappointment': 696,
#  'novels': 697,
#  'anymore': 698,
#  'plan': 699,
#  'waiting': 700,
#  'third': 701,
#  'super': 702,
#  'pleased': 703,
#  'windows': 704,
#  'humor': 705,
#  'send': 706,
#  'alone': 707,
#  'compared': 708,
#  'dvds': 709,
#  'u': 710,
#  'wonder': 711,
#  'king': 712,
#  'attention': 713,
#  'anyway': 714,
#  'noise': 715,
#  'chapters': 716,
#  'basically': 717,
#  'digital': 718,
#  'graphics': 719,
#  'sort': 720,
#  'talk': 721,
#  'covers': 722,
#  'learning': 723,
#  'feels': 724,
#  'choice': 725,
#  'bring': 726,
#  'reviewers': 727,
#  'nearly': 728,
#  'eyes': 729,
#  'content': 730,
#  'contains': 731,
#  'tool': 732,
#  'hits': 733,
#  'feet': 734,
#  'questions': 735,
#  'feature': 736,
#  'various': 737,
#  'none': 738,
#  'men': 739,
#  'dance': 740,
#  'warranty': 741,
#  'condition': 742,
#  'moving': 743,
#  'pain': 744,
#  'note': 745,
#  'range': 746,
#  'chance': 747,
#  'mostly': 748,
#  'singing': 749,
#  'future': 750,
#  'fiction': 751,
#  'parents': 752,
#  'setting': 753,
#  'shame': 754,
#  'fits': 755,
#  'opened': 756,
#  'likes': 757,
#  'device': 758,
#  'difference': 759,
#  'reference': 760,
#  'impressed': 761,
#  'plays': 762,
#  'learned': 763,
#  'enjoyable': 764,
#  'students': 765,
#  'standard': 766,
#  'detail': 767,
#  'ms': 768,
#  'obviously': 769,
#  'pair': 770,
#  'truth': 771,
#  'smell': 772,
#  'upon': 773,
#  'general': 774,
#  'charge': 775,
#  'sell': 776,
#  'x': 777,
#  'okay': 778,
#  'bible': 779,
#  'present': 780,
#  'junk': 781,
#  'points': 782,
#  'flat': 783,
#  'soul': 784,
#  'particular': 785,
#  'alot': 786,
#  'middle': 787,
#  'soft': 788,
#  'brought': 789,
#  'miss': 790,
#  'mistake': 791,
#  'lets': 792,
#  'readers': 793,
#  'button': 794,
#  'thin': 795,
#  'outside': 796,
#  'solid': 797,
#  'immediately': 798,
#  'excited': 799,
#  'weak': 800,
#  'form': 801,
#  'base': 802,
#  'artist': 803,
#  'consider': 804,
#  'straight': 805,
#  'common': 806,
#  'mix': 807,
#  'dry': 808,
#  'lasted': 809,
#  'unique': 810,
#  'fell': 811,
#  'putting': 812,
#  'sex': 813,
#  'development': 814,
#  'boys': 815,
#  'cast': 816,
#  'bother': 817,
#  'beyond': 818,
#  'barely': 819,
#  'office': 820,
#  'touch': 821,
#  'girls': 822,
#  'mention': 823,
#  'episodes': 824,
#  'whether': 825,
#  'garbage': 826,
#  'recipes': 827,
#  'audio': 828,
#  'examples': 829,
#  'market': 830,
#  'soundtrack': 831,
#  'refund': 832,
#  'died': 833,
#  'easier': 834,
#  'format': 835,
#  'listened': 836,
#  'wasted': 837,
#  'somewhat': 838,
#  'sit': 839,
#  'seriously': 840,
#  'skin': 841,
#  'background': 842,
#  'items': 843,
#  'christian': 844,
#  'message': 845,
#  'period': 846,
#  'provides': 847,
#  'web': 848,
#  'ipod': 849,
#  'printer': 850,
#  'pc': 851,
#  'workout': 852,
#  'floor': 853,
#  'photos': 854,
#  'helps': 855,
#  'filter': 856,
#  'whats': 857,
#  'website': 858,
#  'described': 859,
#  'failed': 860,
#  'smaller': 861,
#  'cord': 862,
#  'depth': 863,
#  'ways': 864,
#  'laugh': 865,
#  'forget': 866,
#  'owned': 867,
#  'rate': 868,
#  'mentioned': 869,
#  'became': 870,
#  'provide': 871,
#  'earlier': 872,
#  'lives': 873,
#  'stuck': 874,
#  'doubt': 875,
#  'headphones': 876,
#  'helped': 877,
#  'tight': 878,
#  'talking': 879,
#  'ask': 880,
#  'sweet': 881,
#  'negative': 882,
#  'mystery': 883,
#  'details': 884,
#  'pull': 885,
#  'process': 886,
#  'fairly': 887,
#  'brings': 888,
#  'blade': 889,
#  'missed': 890,
#  'picked': 891,
#  'properly': 892,
#  'table': 893,
#  'starts': 894,
#  'cold': 895,
#  'normal': 896,
#  'hell': 897,
#  'seat': 898,
#  'college': 899,
#  'cup': 900,
#  'despite': 901,
#  'tells': 902,
#  'trouble': 903,
#  'six': 904,
#  'test': 905,
#  'laptop': 906,
#  'historical': 907,
#  'exciting': 908,
#  'sony': 909,
#  'possible': 910,
#  'versions': 911,
#  'powerful': 912,
#  'science': 913,
#  'wall': 914,
#  'average': 915,
#  'shape': 916,
#  'places': 917,
#  'remove': 918,
#  'leaves': 919,
#  'filled': 920,
#  'horror': 921,
#  'fix': 922,
#  'sleep': 923,
#  'kitchen': 924,
#  'added': 925,
#  'practice': 926,
#  'slightly': 927,
#  'events': 928,
#  'comedy': 929,
#  'switch': 930,
#  'romance': 931,
#  'knowledge': 932,
#  'fully': 933,
#  'late': 934,
#  'trip': 935,
#  'site': 936,
#  'reviewer': 937,
#  'published': 938,
#  'mess': 939,
#  'bass': 940,
#  'crap': 941,
#  'cause': 942,
#  'opening': 943,
#  'imagine': 944,
#  'plain': 945,
#  'near': 946,
#  'apparently': 947,
#  'step': 948,
#  'players': 949,
#  'email': 950,
#  'fascinating': 951,
#  'shes': 952,
#  'sets': 953,
#  'continue': 954,
#  'minute': 955,
#  'morning': 956,
#  'crazy': 957,
#  'vocals': 958,
#  'final': 959,
#  'asked': 960,
#  'key': 961,
#  'typical': 962,
#  'hearing': 963,
#  'throw': 964,
#  'shipped': 965,
#  'forever': 966,
#  'warm': 967,
#  'facts': 968,
#  'changed': 969,
#  'sing': 970,
#  'ends': 971,
#  'moves': 972,
#  'ice': 973,
#  'anywhere': 974,
#  'career': 975,
#  'club': 976,
#  'impossible': 977,
#  'internet': 978,
#  'obvious': 979,
#  'attempt': 980,
#  'state': 981,
#  'lead': 982,
#  'rating': 983,
#  'particularly': 984,
#  'pass': 985,
#  'city': 986,
#  'dollars': 987,
#  'per': 988,
#  'loose': 989,
#  'fantasy': 990,
#  'cheaper': 991,
#  'concept': 992,
#  'whatever': 993,
#  'finding': 994,
#  'admit': 995,
#  'wow': 996,
#  'study': 997,
#  'avoid': 998,
#  'replaced': 999,
#  'bunch': 1000,
#  ...}

# %%
df_inf_transform = t.texts_to_sequences(df_inf_transform)

# %%
# Padding the dataset to a maximum review length in words

df_inf_transform = pad_sequences(df_inf_transform, maxlen=102) # max len = 102 words

# %%
df_inf_transform
# Out:
# array([[    0,     0,     0, ...,    79,   654,  2166],
#        [    0,     0,     0, ...,  5548,   628,   149],
#        [    0,     0,     0, ...,     1,  1814,  3296],
#        ...,
#        [    0,     0,     0, ...,     1, 30390,   405],
#        [    0,     0,     0, ...,   896,   303,  1367],
#        [    0,     0,     0, ...,     1,  8037,   661]], dtype=int32)

# %%
# Predict using selected model
y_pred_inf = model_gruimp.predict(df_inf_transform)
y_pred_inf = np.where(y_pred_inf >= 0.5, 1, 0)
y_pred_inf
# Out:
# 1/1 [==============================] - 1s 1s/step
# array([[1],
#        [0],
#        [1],
#        [1],
#        [0],
#        [1],
#        [0],
#        [0],
#        [1],
#        [0]])

# %%
# Creating dataframe prediction
y_pred_inf = pd.DataFrame(y_pred_inf, columns=['Prediction'],index=df_inf_copy.index)

# Comparing the real target and prediction
model_inf = pd.concat([df_inf_copy['class_index'], y_pred_inf['Prediction']], axis=1).sort_index()
model_inf
# Out:
#        class_index  Prediction
# 0  Positive Review           1
# 1  Positive Review           0
# 2  Positive Review           1
# 3  Negative Review           1
# 4  Negative Review           0
# 5  Positive Review           1
# 6  Positive Review           0
# 7  Positive Review           0
# 8  Positive Review           1
# 9  Negative Review           0

# %%
model_inf.Prediction.replace({0:'Negative Review',1:'Positive Review'}, inplace=True)

# %%
model_inf
# Out:
#        class_index       Prediction
# 0  Positive Review  Positive Review
# 1  Positive Review  Negative Review
# 2  Positive Review  Positive Review
# 3  Negative Review  Positive Review
# 4  Negative Review  Negative Review
# 5  Positive Review  Positive Review
# 6  Positive Review  Negative Review
# 7  Positive Review  Negative Review
# 8  Positive Review  Positive Review
# 9  Negative Review  Negative Review

# %% [markdown]
# The model we created has 70% accuracy for this data inference, this might be due to the presence of new words that are not in the vocabulary.
